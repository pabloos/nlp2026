# %% [markdown]
# # NLP 2026 — Índice de Módulos
#
# ---
#
# ### [Dataset Review — Análisis exploratorio de Twitter y Amazon](data_review_visual.ipynb)
# Distribución de clases · Longitud · Tokens especiales · Bigramas · VADER · Calidad del dataset
#
# ---
#
# ### [Módulo 1 — Fundamentos de NLP y Preprocesamiento de Texto](modulo1_fundamentos_nlp.ipynb)
# Introducción al ecosistema NLP/NLU/NLG · Tokenización · Stopwords · Stemming vs Lematización · Expresiones regulares
#
# ---
#
# ### [Módulo 2 — Vectorización de Texto y Modelos Clásicos](modulo2_vectorizacion_modelos_clasicos.ipynb)
# Bag of Words · TF-IDF · N-gramas · Pipeline sklearn · Naive Bayes · Regresión Logística · Métricas de evaluación
#
# ---
#
# ### [Lab 1 — Sentiment Analysis: Mini-Kaggle competitivo](lab1_sentiment_student.ipynb)
# TF-IDF · Logistic Regression · Preprocesamiento · Leaderboard en tiempo real · Techo bag-of-words
#
# ---
#
# ### [Módulo 3 — Word Embeddings y Análisis de Sentimientos](modulo3_embeddings_sentimientos.ipynb)
# Limitaciones de BoW · Word2Vec · GloVe · Análisis de sentimientos léxico (VADER) vs ML con embeddings
#
# ---
#
# ### [Lab 2 — Word Embeddings para Reseñas de Videojuegos](lab2_videogames_embeddings_student.ipynb)
# GloVe · Word2Vec · Matriz de co-ocurrencia · Similitud coseno · Búsqueda semántica
#
# ---
#
# ### [Módulo 4 — Modelado de Tópicos y Tareas de NLU](modulo4_topic_modeling_nlu.ipynb)
# LDA · Selección de K con coherencia · NER · POS Tagging · Análisis de dependencias
#
# ---
#
# ### [Lab 3 — Pipeline NLP: POS · NER · Dependencias · LDA](lab3_nlp_pipeline_noticias_es.ipynb)
# spaCy · Gensim · POS tagging · NER · Extracción SVO · Topic modeling · Cruce NER×LDA
#
# ---
#
# ### [Módulo 5 — Introducción a los Modelos de Lenguaje y Transformers](modulo5_transformers_modelos_preentrenados.ipynb)
# RNN/LSTM · Mecanismo de atención · Arquitectura Transformer · BERT vs GPT · Hugging Face pipelines
#
# ---
#
# ### [Módulo 6 — Aplicaciones Prácticas con LLMs](modulo6_llms_aplicaciones.ipynb)
# Ecosistema LLMs · Fine-tuning vs API · Prompt Engineering · Aumentación sintética · Etiquetado zero-shot · RAG
#
# ---

# %%
# Menú interactivo — ejecuta esta celda para ver el índice con enlaces clicables
from IPython.display import display, HTML

COLAB = "https://colab.research.google.com/github/pabloos/nlp2026/blob/main/notebooks/"

modulos = [
    ("Datos",     "Análisis exploratorio de los datasets",
     "Twitter · Amazon · Tokens especiales · Bigramas · VADER",
     "data_review_visual.ipynb", "#FDEBD0"),
    ("Módulo 1",  "Fundamentos de NLP y Preprocesamiento",
     "Tokenización · Stopwords · Stemming · Regex",
     "modulo1_fundamentos_nlp.ipynb", "#AED6F1"),
    ("Módulo 2",  "Vectorización y Modelos Clásicos",
     "BoW · TF-IDF · N-gramas · Naive Bayes · Regresión Logística",
     "modulo2_vectorizacion_modelos_clasicos.ipynb", "#A9DFBF"),
    ("Lab 1",     "Sentiment Analysis: Mini-Kaggle competitivo",
     "TF-IDF · LR · Leaderboard en tiempo real · Techo bag-of-words",
     "lab1_sentiment_student.ipynb", "#D5F5E3"),
    ("Módulo 3",  "Word Embeddings y Análisis de Sentimientos",
     "Word2Vec · GloVe · VADER · Clasificación con embeddings",
     "modulo3_embeddings_sentimientos.ipynb", "#FAD7A0"),
    ("Lab 2",     "Word Embeddings para Reseñas de Videojuegos",
     "GloVe · Word2Vec · Matriz co-ocurrencia · Similitud coseno · Búsqueda semántica",
     "lab2_videogames_embeddings_student.ipynb", "#FDFEA0"),
    ("Módulo 4",  "Modelado de Tópicos y NLU",
     "LDA · Coherencia · NER · POS Tagging · Dependencias",
     "modulo4_topic_modeling_nlu.ipynb", "#D7BDE2"),
    ("Lab 3",     "Pipeline NLP: POS · NER · Dependencias · LDA",
     "spaCy · Gensim · POS tagging · NER · Extracción SVO · Topic modeling · Cruce NER×LDA",
     "lab3_nlp_pipeline_noticias_es.ipynb", "#D0ECE7"),
    ("Módulo 5",  "Transformers y Modelos Pre-entrenados",
     "RNN → Atención → BERT · GPT · Hugging Face pipelines",
     "modulo5_transformers_modelos_preentrenados.ipynb", "#F9E79F"),
    ("Módulo 6",  "Aplicaciones Prácticas con LLMs",
     "Prompt Engineering · Augmentación · Zero-shot labeling · RAG",
     "modulo6_llms_aplicaciones.ipynb", "#FDEBD0"),
]

cards = ""
for num, titulo, subtitulo, link, color in modulos:
    colab_btn = (
        f'<a href="{COLAB}{link}" target="_blank" style="text-decoration:none;float:right;margin-top:2px;">'
        f'<img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"></a>'
    )
    cards += f"""
    <div style="
        background:{color}; border-radius:10px; padding:14px 18px;
        margin:8px 0; border-left:5px solid #555;
        font-family: -apple-system, sans-serif; overflow:hidden;
    ">
      {colab_btn}
      <a href="{link}" style="text-decoration:none; color:inherit;">
        <span style="font-size:11px;color:#555;font-weight:600;text-transform:uppercase;letter-spacing:1px">{num}</span><br>
        <span style="font-size:16px;font-weight:700;color:#1a1a1a">{titulo}</span><br>
        <span style="font-size:12px;color:#444">{subtitulo}</span>
      </a>
    </div>"""

display(HTML(f"""
<div style="max-width:760px;margin:0 auto;">
  <h2 style="font-family:-apple-system,sans-serif;color:#1a1a1a;border-bottom:2px solid #ddd;padding-bottom:8px">
    NLP 2026 — Índice de Módulos
  </h2>
  {cards}
</div>
"""))
